# %%
import pandas as pd

# %%
# Reading in time matrix
timeMatrix = pd.read_csv('C:/Users/Aidan/OneDrive - Simon Fraser University (1sfu)/Garbage Route Optimization/timeMatrix.csv', index_col=0)

# %%
# Reading in locations
locations = pd.read_csv('C:/Users/Aidan/OneDrive - Simon Fraser University (1sfu)/Garbage Route Optimization/locations_updated.csv', index_col=0)

# %%
# Filtering out garbage
locations = locations[~(locations['Address'] == 'NO ADDRESS, Port Coquitlam, BC, Canada')]

# %%
# Reading in zones
zones = pd.read_csv('C:/Users/Aidan/OneDrive - Simon Fraser University (1sfu)/Garbage Route Optimization/poco-allzones.csv', index_col=0)
zones.index = zones.index + ', Port Coquitlam, BC, Canada'

# %%
# Selecting zone
zones = zones[(zones['Garbage Zone'] == 1)]

# %%
row = pd.Series({'Garbage Zone':1.0},name='1737 Broadway St Port Coquitlam, BC, Canada')

# %%
zones = zones.append(row)

# %%
timeMatrixFiltered = timeMatrix.iloc[timeMatrix.index.isin(zones.index),timeMatrix.index.isin(zones.index)]

# %%
timeWindows = []
for i in range(len(timeMatrix)):
    house = timeMatrix.index[i].split(' ')
    street = ' '.join(house[1:-4])
    
 
    if street == 'LINCOLN AVE,':
        timeWindows.append((0,30))
    else:
        timeWindows.append((0,500000000000000000000))
# Out:
# ['1735', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1532', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['934', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1850', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1857', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2162', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2134', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1599', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2656', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1612', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1843', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1851', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1591', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2712', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['998', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1595', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2672', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1635', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1819', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['944', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1743', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1614', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1823', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['902', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2562', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2590', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1657', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1775', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2640', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1039', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2556', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2582', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['922', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2666', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1620', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1008', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1007', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1842', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['910', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1068', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1858', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['918', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1647', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1767', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2150', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2598', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2570', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1570', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1013', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1791', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['954', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2168', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2578', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2136', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['986', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1876', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1613', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2688', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2156', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2602', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1076', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2130', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1540', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['925', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1625', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2624', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1783', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2680', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1016', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1054', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2696', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2616', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2648', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1080', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2126', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1664', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2704', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1638', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2586', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1040', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1751', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2632', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1048', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1081', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1880', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1536', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1863', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1036', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['972', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['960', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1585', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1028', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1759', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1653', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1550', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['1551', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
# ['2608', 'LINCOLN', 'AVE,', 'Port', 'Coquitlam,', 'BC,', 'Canada']
# LINCOLN AVE,
